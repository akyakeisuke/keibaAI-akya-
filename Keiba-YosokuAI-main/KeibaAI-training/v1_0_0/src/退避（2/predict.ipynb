# %%
import lightgbm as lgb
from pathlib import Path
import preprocessing as preprpcessing

import pandas as pd
import preprocessing
from pathlib import Path

DATA_DIR = Path("..","data")
COMMON_DATA_DIR = Path("..","..","common","src","data")
RAWDF_DIR = COMMON_DATA_DIR/"rawdf"
INPUT_DIR = COMMON_DATA_DIR / "rawdf"
MAPPING_DIR = COMMON_DATA_DIR / "mapping"
OUTPUT_DIR = Path("..", "data", "01_preprocessed")
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

# %load_ext autoreload

# %%
# %autoreload

# %%
df = pd.read_csv(INPUT_DIR / "20241124_202405050812racetyokuzen.csv", sep="\t")

# %%
df
# Out:
#     Unnamed: 0       race_id    horse_id  jockey_id  trainer_id  sex  age  \
# 0            0  202405050812  2020190005       5271        5701    2    4
# 1            1  202405050812  2019105748       1179        1176    0    5
# 2            2  202405050812  2019105283        666        1061    0    5
# 3            3  202405050812  2019105346       5473        1157    0    5
# 4            4  202405050812  2019104447       1157        1070    2    5
# 5            5  202405050812  2019105195       1126        1070    0    5
# 6            6  202405050812  2021110048       1163        1075    0    3
# 7            7  202405050812  2020190003       5366        5518    0    4
# 8            8  202405050812  2021105643       5339        1126    1    3
# 9            9  202405050812  2020103650       5495        1103    0    4
# 10          10  202405050812  2016106606       1135        1002    0    8
# 11          11  202405050812  2020102899       1170        1038    0    4
# 12          12  202405050812  2020190004       5661       90483    0    4
# 13          13  202405050812  2019104740       1088        1118    1    5
#
#     weight  weight_diff  yosou_odds  popularity  impost  wakuban  umaban
# 0      496            0        19.3           9    58.0        1       1
# 1      430            4        34.1          10    58.0        2       2
# 2      510            6         2.4           1    58.0        3       3
# 3      468           -2         7.1           3    58.0        3       4
# 4      478            8        40.7          11    58.0        4       5
# 5      492           -6        61.1          12    58.0        4       6
# 6      488            0        14.8           7    56.0        5       7
# 7      454            0        12.6           5    58.0        5       8
# 8      494            4         3.3           2    54.0        6       9
# 9      470            0        12.8           6    58.0        6      10
# 10     530            4       279.0          14    58.0        7      11
# 11     476            8        15.8           8    58.0        7      12
# 12     440            0       125.7          13    58.0        8      13
# 13     500            0        10.6           4    56.0        8      14

# %%
INPUT_DIR2 = Path("..","data","02_features")
features = pd.read_csv(INPUT_DIR2 / "features.csv", sep = "\t")

# %%
print(features)
# Out:
#             race_id    horse_id        date  jockey_id  trainer_id  rank  sex  \
# 0      202301010101  2021100648  2023-07-22       1095        1128     5    1
# 1      202301010101  2021100159  2023-07-22       1157        1186     6    0
# 2      202301010101  2021100265  2023-07-22       1197        1192     7    1
# 3      202301010101  2021105553  2023-07-22       5339        1160     4    1
# 4      202301010101  2021101429  2023-07-22       1170        1026     1    0
# ...             ...         ...         ...        ...         ...   ...  ...
# 88358  202410030812  2020101594  2024-07-21       1187        1135     3    0
# 88359  202410030812  2021104131  2024-07-21       1018        1003     5    0
# 88360  202410030812  2020103212  2024-07-21       5212        1061     7    0
# 88361  202410030812  2020103550  2024-07-21       1154        1121    10    0
# 88362  202410030812  2021101090  2024-07-21       1204        1170    14    1
#
#        age  weight  weight_diff  ...  rank_1race  prize_1race  rank_3races  \
# 0        2     434          -10  ...         4.0         83.0     4.500000
# 1        2     454           -6  ...         8.0          0.0     8.000000
# 2        2     404           -2  ...         5.0         72.0     5.000000
# 3        2     450            2  ...         4.0        110.0     4.000000
# 4        2     452           -4  ...         2.0        290.0     2.000000
# ...    ...     ...          ...  ...         ...          ...          ...
# 88358    4     446            0  ...         6.0          0.0     4.333333
# 88359    3     474           -2  ...         4.0        120.0     4.666667
# 88360    4     522            2  ...         1.0        800.0     4.333333
# 88361    4     484            6  ...         8.0          0.0     5.000000
# 88362    3     456            0  ...        12.0          0.0     8.666667
#
#        prize_3races  rank_5races  prize_5races  rank_10races  prize_10races  \
# 0         77.500000          4.5         77.50      4.500000      77.500000
# 1          0.000000          8.0          0.00      8.000000       0.000000
# 2         72.000000          5.0         72.00      5.000000      72.000000
# 3        110.000000          4.0        110.00      4.000000     110.000000
# 4        290.000000          2.0        290.00      2.000000     290.000000
# ...             ...          ...           ...           ...            ...
# 88358    106.666667          3.0        104.00      2.600000     133.300000
# 88359    106.666667          4.0        183.24      3.285714     250.885714
# 88360    373.333333          4.0        284.00      3.833333     260.000000
# 88361    106.666667          4.2        144.00      4.300000     140.000000
# 88362      0.000000          5.8        154.00      5.500000     146.666667
#
#        rank_1000races  prize_1000races
# 0            4.500000        77.500000
# 1            8.000000         0.000000
# 2            5.000000        72.000000
# 3            4.000000       110.000000
# 4            2.000000       290.000000
# ...               ...              ...
# 88358        3.666667       114.266667
# 88359        3.285714       250.885714
# 88360        3.833333       260.000000
# 88361        5.062500       126.875000
# 88362        5.500000       146.666667
#
# [88363 rows x 32 columns]

# %%
df_prediction = pd.merge(features,df["horse_id"], on="horse_id")

# %%
#df_prediction["horse_id"].unique()
df_prediction
# Out:
#          race_id    horse_id        date  jockey_id  trainer_id  rank  sex  \
# 0   202301010511  2019105748  2023-08-05       5203        1010     1    0
# 1   202301020411  2019105195  2023-08-20       5509        1070     4    0
# 2   202302020611  2019105748  2023-07-16       5203        1010     3    0
# 3   202304010411  2016106606  2023-05-07       1179        1183     1    0
# 4   202304030102  2021105643  2023-08-12       5339        1126     1    1
# ..           ...         ...         ...        ...         ...   ...  ...
# 70  202408050211  2019105748  2024-10-06       1179        1176    11    0
# 71  202408050411  2021105643  2024-10-13       5339        1126     1    1
# 72  202409010811  2019105748  2024-03-17       1179        1176     3    0
# 73  202409020411  2020102899  2024-03-31       1170        1038     7    0
# 74  202409020611  2021105643  2024-04-07       5627        1126    13    1
#
#     age  weight  weight_diff  ...  rank_1race  prize_1race  rank_3races  \
# 0     4     422           -6  ...         3.0       1108.0     1.666667
# 1     4     508            0  ...         2.0          0.0     3.333333
# 2     4     428            8  ...         1.0       1873.6     2.333333
# 3     7     534           -2  ...         8.0          0.0     5.000000
# 4     2     476            6  ...         2.0        290.0     2.000000
# ..  ...     ...          ...  ...         ...          ...          ...
# 70    5     426           -2  ...         1.0      22273.0     2.000000
# 71    3     490            8  ...         1.0      17743.3     5.000000
# 72    5     426            0  ...         1.0       5799.4     1.666667
# 73    4     456          -10  ...         4.0       1000.0     5.000000
# 74    3     488            8  ...         1.0       2935.7     1.333333
#
#     prize_3races  rank_5races  prize_5races  rank_10races  prize_10races  \
# 0    1518.933333     2.200000   1096.360000      2.900000     651.980000
# 1    3015.000000     3.600000   2869.000000      2.857143    2726.614286
# 2    1201.266667     2.000000    936.760000      3.100000     546.380000
# 3    1454.333333     7.600000    872.600000      5.100000    1266.220000
# 4     290.000000     2.000000    290.000000      2.000000     290.000000
# ..           ...          ...           ...           ...            ...
# 70  10965.333333     1.600000   8305.100000      1.900000    4700.730000
# 71   6893.000000     3.600000   4303.800000      3.600000    4303.800000
# 72   3245.833333     1.400000   2637.260000      1.900000    1507.130000
# 73   2128.733333     3.800000   4279.680000      2.750000    6083.512500
# 74   1258.566667     1.333333   1258.566667      1.333333    1258.566667
#
#     rank_1000races  prize_1000races
# 0         3.466667       467.453333
# 1         2.857143      2726.614286
# 2         3.500000       421.700000
# 3         6.970588       631.608824
# 4         2.000000       290.000000
# ..             ...              ...
# 70        3.000000      2426.865000
# 71        3.600000      4303.800000
# 72        3.176471       920.076471
# 73        2.750000      6083.512500
# 74        1.333333      1258.566667
#
# [75 rows x 32 columns]

# %%
df_prediction.columns
# Out:
# Index(['race_id', 'horse_id', 'date', 'jockey_id', 'trainer_id', 'rank', 'sex',
#        'age', 'weight', 'weight_diff', 'tansho_odds', 'popularity', 'impost',
#        'wakuban', 'umaban', 'race_type', 'around', 'course_len', 'weather',
#        'ground_state', 'race_class', 'place', 'rank_1race', 'prize_1race',
#        'rank_3races', 'prize_3races', 'rank_5races', 'prize_5races',
#        'rank_10races', 'prize_10races', 'rank_1000races', 'prize_1000races'],
#       dtype='object')

# %%
feature_cols = [
    'horse_id', 
    'jockey_id', 
    'trainer_id', 
    'sex',
    'age', 
    'weight', 
    'weight_diff', 
    # 'tansho_odds', 
    # 'popularity', 
    'impost',
    'wakuban', 
    'umaban', 
    'race_type', 
    'around', 
    'course_len', 
    'weather',
    'ground_state', 
    'race_class',
    'place',
    'rank_1race',
    'prize_1race',
    'rank_3races',
    'prize_3races',
    'rank_5races',
    'prize_5races',
    'rank_10races',
    'prize_10races',
    'rank_1000races',
    'prize_1000races'
]
#説明変数
X = df_prediction[feature_cols]
#目的変数
df_prediction["target"] = (df_prediction["rank"] == 1).astype(int)

# %%
train_df = df_prediction.query("date < '2024-08-01' and date > '2024-01-01'")
test_df = df_prediction.query("date >= '2024-08-01'")

# %%
len(train_df),len(test_df)
# Out:
# (25, 7)

# %%
#データセットの作成
lgb_train = lgb.Dataset(
    train_df[feature_cols], train_df["target"]
)

lgb_test = lgb.Dataset(
    test_df[feature_cols], test_df["target"]
)

#パラメータの設定
params = {
    "objective": "binary", # 二値分類
    "metric": "binary_logloss", # 予測誤差
    "random_state":100 # 実行ごとに同じ結果を得るための設定
}

#学習の実行
model2 = lgb.train(
    params = params,
    train_set = lgb_train,
    valid_sets = [lgb_train, lgb_test],
    callbacks = [lgb.log_evaluation()]
)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 6, number of negative: 19
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 25, number of used features: 0
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.240000 -> initscore=-1.152680
# [LightGBM] [Info] Start training from score -1.152680
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [1]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [2]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [3]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [4]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [5]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [6]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [7]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [8]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [9]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [10]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [11]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [12]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [13]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [14]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [15]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [16]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [17]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [18]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [19]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [20]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [21]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [22]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [23]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [24]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [25]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [26]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [27]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [28]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [29]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [30]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [31]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [32]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [33]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [34]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [35]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [36]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [37]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [38]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [39]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [40]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [41]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [42]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [43]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [44]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [45]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [46]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [47]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [48]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [49]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [50]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [51]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [52]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [53]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [54]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [55]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [56]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [57]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [58]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [59]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [60]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [61]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [62]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [63]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [64]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [65]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [66]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [67]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [68]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [69]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [70]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [71]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [72]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [73]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [74]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [75]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [76]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [77]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [78]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [79]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [80]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [81]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [82]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [83]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [84]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [85]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [86]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [87]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [88]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [89]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [90]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [91]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [92]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [93]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [94]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [95]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [96]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [97]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [98]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [99]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [100]	training's binary_logloss: 0.55108	valid_1's binary_logloss: 0.603774

# %%
#馬体重はハンドで加工済み

# レース結果テーブルの前処理
# results_predict = preprpcessing.process_race(
#     save_filename="20241124_202405050812results.csv"
# )
results_predict = pd.read_csv(OUTPUT_DIR/ "20241124_202405050812racetyokuzen.csv", sep="\t")

feature_cols = [
    'horse_id', 
    'jockey_id', 
    'trainer_id', 
    'sex',
    'age', 
    'weight', 
    'weight_diff', 
    # 'tansho_odds', 
    # 'popularity', 
    'impost',
    'wakuban', 
    'umaban', 
    'race_type', 
    'around', 
    'course_len', 
    'weather',
    'ground_state', 
    'race_class',
    'place',
    'rank_1race',
    'prize_1race',
    'rank_3races',
    'prize_3races',
    'rank_5races',
    'prize_5races',
    'rank_10races',
    'prize_10races',
    'rank_1000races',
    'prize_1000races'
]


# モデルの読み込み
#model = lgb.Booster(model_file=Path("..", "model", "model.txt"))
#model = lgb.Booster(model_file=Path("..", "model", "model_alldata.txt"))
#model = lgb.Booster(model_file=Path("..", "model", "modelbefore20240601.txt"))
model = lgb.Booster(model_file=Path("..", "model", "modelafter20240101.txt"))

# %%
results_predict = pd.merge(results_predict,df_prediction[["horse_id","rank_1race","prize_1race","rank_3races","prize_3races","rank_5races","prize_5races","rank_10races","prize_10races","rank_1000races","prize_1000races"]],on = "horse_id")

# %%
results_predict["race_type"] = 1
results_predict["around"] = 1
results_predict["course_len"] = 2400
results_predict["weather"] = 0
results_predict["ground_state"] = 0
results_predict["race_class"] = 8
results_predict["place"] = results_predict["race_id"].astype(str).str[4:6].astype(int)

# %%
predict_df = (
    results_predict
    .sort_values(by="race_id", ascending=False)
    .drop_duplicates(subset="horse_id", keep="first")
)

# %%
predict_df["horse_id"].unique()
# Out:
# array([2020190005, 2019105748, 2019105283, 2019105346, 2019104447,
#        2019105195, 2021110048, 2020190003, 2021105643, 2020103650,
#        2016106606, 2020102899, 2020190004, 2019104740])

# %%
predict_df
# Out:
#     Unnamed: 0       race_id    horse_id  jockey_id  trainer_id  sex  age  \
# 0            1  202405050812  2019105748       1179        1176    0    5
# 10           2  202405050812  2019105283        666        1061    0    5
# 16           3  202405050812  2019105346       5473        1157    0    5
# 23           4  202405050812  2019104447       1157        1070    2    5
# 30           5  202405050812  2019105195       1126        1070    0    5
# 34           6  202405050812  2021110048       1163        1075    0    3
# 40           8  202405050812  2021105643       5339        1126    1    3
# 46           9  202405050812  2020103650       5495        1103    0    4
# 52          10  202405050812  2016106606       1135        1002    0    8
# 61          11  202405050812  2020102899       1170        1038    0    4
# 71          13  202405050812  2019104740       1088        1118    1    5
#
#     weight  weight_diff  yosou_odds  ...  prize_10races  rank_1000races  \
# 0      430            4        34.1  ...     651.980000        3.466667
# 10     510            6         2.4  ...    4987.344444        3.666667
# 16     468           -2         7.1  ...    4831.940000        3.454545
# 23     478            8        40.7  ...     601.912500        2.500000
# 30     492           -6        61.1  ...    2726.614286        2.857143
# 34     488            0        14.8  ...            NaN             NaN
# 40     494            4         3.3  ...     290.000000        2.000000
# 46     470            0        12.8  ...     839.100000        1.500000
# 52     530            4       279.0  ...    1266.220000        6.970588
# 61     476            8        15.8  ...    9089.900000        1.000000
# 71     500            0        10.6  ...            NaN             NaN
#
#     prize_1000races  race_type  around  course_len  weather  ground_state  \
# 0        467.453333          1       1        2400        0             0
# 10      4987.344444          1       1        2400        0             0
# 16      4456.309091          1       1        2400        0             0
# 23       601.912500          1       1        2400        0             0
# 30      2726.614286          1       1        2400        0             0
# 34              NaN          1       1        2400        0             0
# 40       290.000000          1       1        2400        0             0
# 46       839.100000          1       1        2400        0             0
# 52       631.608824          1       1        2400        0             0
# 61      9089.900000          1       1        2400        0             0
# 71              NaN          1       1        2400        0             0
#
#     race_class  place
# 0            8      5
# 10           8      5
# 16           8      5
# 23           8      5
# 30           8      5
# 34           8      5
# 40           8      5
# 46           8      5
# 52           8      5
# 61           8      5
# 71           8      5
#
# [11 rows x 31 columns]

# %%
# テストデータに対して予測をしてみる
predict_df["pred"] = model.predict(predict_df[feature_cols])

# 確認に必要なデータだけ抽出
df = predict_df[
    [
        "race_id",
        "umaban",
        "pred",
        "yosou_odds",
        "popularity"
    ]
].copy()
df.sort_values("pred", ascending=False)
# Out:
#          race_id  umaban      pred  yosou_odds  popularity
# 40  202405050812       9  0.345620         3.3           2
# 16  202405050812       4  0.167357         7.1           3
# 23  202405050812       5  0.165413        40.7          11
# 30  202405050812       6  0.153686        61.1          12
# 46  202405050812      10  0.141713        12.8           6
# 71  202405050812      14  0.121801        10.6           4
# 0   202405050812       2  0.106063        34.1          10
# 10  202405050812       3  0.100780         2.4           1
# 34  202405050812       7  0.075018        14.8           7
# 61  202405050812      12  0.060106        15.8           8
# 52  202405050812      11  0.033828       279.0          14

# %%
# テストデータに対して予測をしてみる
predict_df["pred"] = model.predict(predict_df[feature_cols])

# 確認に必要なデータだけ抽出
df = predict_df[
    [
        "race_id",
        "umaban",
        "pred",
        "yosou_odds",
        "popularity"
    ]
].copy()
df.sort_values("pred", ascending=False)
# Out:
#          race_id  umaban      pred  yosou_odds  popularity
# 40  202405050812       9  0.366043         3.3           2
# 16  202405050812       4  0.159362         7.1           3
# 46  202405050812      10  0.150480        12.8           6
# 30  202405050812       6  0.145641        61.1          12
# 10  202405050812       3  0.141401         2.4           1
# 23  202405050812       5  0.137387        40.7          11
# 61  202405050812      12  0.113924        15.8           8
# 34  202405050812       7  0.090040        14.8           7
# 71  202405050812      14  0.087589        10.6           4
# 0   202405050812       2  0.073373        34.1          10
# 52  202405050812      11  0.016207       279.0          14

# %%
# テストデータに対して予測をしてみる
results_predict["pred"] = model2.predict(results_predict[feature_cols])

# 確認に必要なデータだけ抽出
df2 = results_predict[
    [
        "race_id",
        "umaban",
        "pred",
        "yosou_odds",
        "popularity"
    ]
].copy()
df2.sort_values("pred", ascending=False)
# Out:
#          race_id  umaban  pred  yosou_odds  popularity
# 0   202405050812       2  0.24        34.1          10
# 1   202405050812       2  0.24        34.1          10
# 2   202405050812       2  0.24        34.1          10
# 3   202405050812       2  0.24        34.1          10
# 4   202405050812       2  0.24        34.1          10
# ..           ...     ...   ...         ...         ...
# 70  202405050812      12  0.24        15.8           8
# 71  202405050812      14  0.24        10.6           4
# 72  202405050812      14  0.24        10.6           4
# 73  202405050812      14  0.24        10.6           4
# 74  202405050812      14  0.24        10.6           4
#
# [75 rows x 5 columns]

# %%
import graphviz
import matplotlib.pyplot as plt

# %% [markdown]
# # オフライン評価
# 的中率・回収率を見てみる

# %%
df.to_csv(DATA_DIR / "03_prediction" / "all_data_prediction_racetyokuzen.csv", sep="\t", index=False)

# %%
bet_df = (
    df
    .sort_values("pred",ascending=False)
    .groupby("umaban")
    .head(1)
    # .tail(1)
)
bet_df
# Out:
#          race_id  umaban      pred  yosou_odds  popularity
# 12  202405050812       3  0.406124         2.4           1
# 17  202405050812       4  0.306985         7.1           3
# 43  202405050812       9  0.304987         3.3           2
# 49  202405050812      10  0.231949        12.8           6
# 31  202405050812       6  0.188120        61.1          12
# 29  202405050812       5  0.184886        40.7          11
# 7   202405050812       2  0.133675        34.1          10
# 64  202405050812      12  0.118534        15.8           8
# 74  202405050812      14  0.115606        10.6           4
# 36  202405050812       7  0.113338        14.8           7
# 53  202405050812      11  0.032774       279.0          14

# %% [markdown]
# 賭け方
# 単勝　9 チェルヴィニア　1000
#     　3 ドウデュース　500
# 馬連　9-3 500
#      9-4 500
# 3連単　9-3-4 500
# 3連複　9-3-4 1000
#        9-3-11 500
#        9-3-1 500

# %%
df2.to_csv(DATA_DIR / "03_prediction" / "only_syussouba_prediction.csv", sep="\t", index=False)

# %%
bet_df2 = (
    df2
    .sort_values("pred",ascending=False)
    .groupby("umaban")
    .head(1)
    # .tail(1)
)
bet_df2
# Out:
#          race_id  umaban  pred  yosou_odds  popularity
# 0   202405050812       2  0.24        34.1          10
# 10  202405050812       3  0.24         2.4           1
# 16  202405050812       4  0.24         7.1           3
# 23  202405050812       5  0.24        40.7          11
# 30  202405050812       6  0.24        61.1          12
# 34  202405050812       7  0.24        14.8           7
# 40  202405050812       9  0.24         3.3           2
# 46  202405050812      10  0.24        12.8           6
# 52  202405050812      11  0.24       279.0          14
# 61  202405050812      12  0.24        15.8           8
# 71  202405050812      14  0.24        10.6           4

# %% [markdown]
# predの値が一番高いものに、単勝馬券で賭ける場合を考える

# %%
bet_df = (
    evaluation_df.
    .sort_values("pred",ascending=False)
    .groupby("race_id")
    .head(1)
    # .tail(1)
)

# %%
#的中率
bet_df["target"].mean()
# Out:
# np.float64(0.25)

# %%
#返ってくる金額
return_ = ((bet_df["target"] == 1) * bet_df["tansho_odds"]).sum()
return_
# Out:
# np.float64(2.3)

# %%
#賭けた金額
cost = len(bet_df)
cost
# Out:
# 4

# %%
#回収率
return_ / cost
# Out:
# np.float64(0.575)

# %%
import matplotlib

# %% [markdown]
# ## 特徴量重要度
# モデルにインプットしたデータの中で、どの特徴量（列）が一番学習に使われているか

# %%
lgb.plot_importance(model,importance_type="gain")
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
lgb.plot_importance(model2,importance_type="gain")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 lgb.plot_importance(model2,importance_type="gain")
#
# File c:\Users\hisaf\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightgbm\plotting.py:132, in plot_importance(booster, ax, height, xlim, ylim, title, xlabel, ylabel, importance_type, max_num_features, ignore_zero, figsize, dpi, grid, precision, **kwargs)
#     130 if max_num_features is not None and max_num_features > 0:
#     131     tuples = tuples[-max_num_features:]
# --> 132 labels, values = zip(*tuples)
#     134 if ax is None:
#     135     if figsize is not None:
#
# ValueError: not enough values to unpack (expected 2, got 0)
